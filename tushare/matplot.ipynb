# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# 随机生成100个数据
data = pd.Series(np.random.randn(100),index=np.arange(100))
 
# 为了方便观看效果, 我们累加这个数据
data = data.cumsum()

# pandas 数据可以直接观看其可视化形式
data.plot()

plt.show()

# %%
from pylab import *

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)
plot(X,C)
plot(X,S)

show()

# %%
plt.plot([1,2,3])
plt.title("汉字")
plt.show()

# %%
from matplotlib.font_manager import findfont, FontProperties
print(matplotlib.matplotlib_fname())
print(matplotlib.get_configdir())
print(matplotlib.font_manager.FontProperties().get_family())
findfont(FontProperties(family=FontProperties().get_family()))
# Out:
# c:\users\juchen3\.virtualenvs\tushare-srwxh49r\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# C:\Users\juchen3\.matplotlib
# ['sans-serif']
# 'c:\\users\\juchen3\\.virtualenvs\\tushare-srwxh49r\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\YaHei.ttf'
