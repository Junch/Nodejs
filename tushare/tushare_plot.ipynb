# %%
import tushare as ts
import pandas as pd
import numpy as np
df = pd.read_csv('profit.csv',  dtype={'code' : np.str})

# %%
df
# Out:
#       quarter    code   name    roe  net_profit_ratio  gross_profit_rate  \
# 0      2017-3  000717   韶钢松山  79.22              9.44            14.1042
# 1      2017-3  600793   宜宾纸业  65.40             13.31             7.9084
# 2      2017-3  600306    商业城  63.19             18.55            17.8601
# 3      2017-3  000526  *ST紫学  61.03              2.78            31.1212
# 4      2017-3  600768   宁波富邦  57.83             14.95             2.7349
# 5      2017-3  600338   西藏珠峰  56.96             46.50            71.5406
# 6      2017-3  600319   亚星化学  54.48              0.55            10.7853
# 7      2017-3  002925   盈趣科技  52.14             32.25            48.9041
# 8      2017-3  002027   分众传媒  47.20             44.86            72.2835
# 9      2017-3  000513   丽珠集团  40.11             65.10            65.1652
# 10     2017-3  600507   方大特钢  39.93             15.20            29.4450
# 11     2017-3  600230   沧州大化  39.49             30.84            54.8175
# ...

# %%
df.set_index(['quarter', 'code'], inplace=True)
df.sort_index(inplace=True)

# %%
df2 = df.loc[(slice(None), '601318'),:]

# %%
df2
# Out:
#                 name    roe  net_profit_ratio  gross_profit_rate  net_profits  \
# quarter code
# 2016-3  601318  中国平安  14.89             10.34            15.0206      56508.0
# 2016-4  601318  中国平安  16.27              8.75            13.1051      62394.0
# 2017-1  601318  中国平安   5.60              8.67            12.2943      23053.0
# 2017-2  601318  中国平安  10.19              9.36            14.1248      43427.0
# 2017-3  601318  中国平安  14.79             10.00            15.1631      66318.0
#
#                    eps  business_income     bips
# quarter code
# 2016-3  601318  3.0912         546118.0  29.8747
# 2016-4  601318  3.4131         712453.0  38.9739
# 2017-1  601318  1.2610         265643.0  14.5317
# 2017-2  601318  2.3756         463765.0  25.3697
# 2017-3  601318  3.6278         663006.0  36.2689

# %%
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
 
plt.show()

# %%
df2.net_profits.plot.bar()
plt.ylabel('profit')
plt.title('601318')

plt.show()

# %%
# https://pythonspot.com/matplotlib-bar-chart/
# data to plot
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)
 
# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, means_frank, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Frank')
 
rects2 = plt.bar(index + bar_width, means_guido, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Guido')
 
plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
df651 = df.loc[(slice(None), '000651'),:]
df333 = df.loc[(slice(None), '000333'),:]

# %%
df333
# Out:
#                 name    roe  net_profit_ratio  gross_profit_rate  net_profits  \
# quarter code
# 2016-3  000333  美的集团  21.93             11.00            27.9694    12807.993
# 2016-4  000333  美的集团  24.02              9.23            27.3060    14684.357
# 2017-1  000333  美的集团   6.64              7.28            25.0570     4352.587
# 2017-2  000333  美的集团  16.30              8.68            25.2302    10811.322
# 2017-3  000333  美的集团  21.05              8.02            25.3488    14998.175
#
#                    eps  business_income     bips
# quarter code
# 2016-3  000333  1.9855       116378.417  18.0416
# 2016-4  000333  2.2735       159044.041  24.6245
# 2017-1  000333  0.6731        59755.914   9.2420
# 2017-2  000333  1.6582       124450.065  19.0884
# 2017-3  000333  2.2904       186948.866  28.5498

# %%
n_groups = 5
means_frank = df651.net_profits
means_guido = df333.net_profits
 
# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.36
opacity = 0.8
 
rects1 = plt.bar(index, means_frank, bar_width,
                 alpha=opacity,
                 color='b',
                 label='000651')
 
rects2 = plt.bar(index + bar_width, means_guido, bar_width,
                 alpha=opacity,
                 color='g',
                 label='000333')
 
plt.xlabel('quarter')
plt.ylabel('net profit')
plt.title('net profit compare')
plt.xticks(index+bar_width/2.0, df651.index.get_level_values('quarter'))
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
df651.index.get_level_values('quarter')
# Out:
# Index([u'2016-3', u'2016-4', u'2017-1', u'2017-2', u'2017-3'], dtype='object', name=u'quarter')

# %%
df651.index.tolist()
# Out:
# [('2016-3', '000651'),
#  ('2016-4', '000651'),
#  ('2017-1', '000651'),
#  ('2017-2', '000651'),
#  ('2017-3', '000651')]

# %%
df651.index.values
# Out:
# array([('2016-3', '000651'), ('2016-4', '000651'), ('2017-1', '000651'),
#        ('2017-2', '000651'), ('2017-3', '000651')], dtype=object)

# %%
df651.index.get_values()
# Out:
# array([('2016-3', '000651'), ('2016-4', '000651'), ('2017-1', '000651'),
#        ('2017-2', '000651'), ('2017-3', '000651')], dtype=object)
