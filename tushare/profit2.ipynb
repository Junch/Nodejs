# %%
# -*- coding: utf-8 -*-
# %matplotlib inline

import tushare as ts
import pandas as pd
import numpy as np

df = pd.read_csv('profit.csv', dtype={'code' : np.str}, parse_dates=['quarter'])
df.quarter = df.quarter.dt.to_period("Q")

# %%
import profit2
periods = {'start':'2015Q1', 'end':'2017Q4', 'year': False}
profit2.compare_item(df, periods,'net_profits', ['000651', '601668', '600886', '600900', '600066'], '净利润比较')
# Out:
# 1517331567.602484

# %%
periods = {'start':'2012Q1', 'end':'2017Q4', 'year': True}
profit2.compare_item(df, periods,'net_profits', ['000651', '601668', '600886', '600900', '600066'], '净利润比较')
# Out:
# 1517331568.274341
